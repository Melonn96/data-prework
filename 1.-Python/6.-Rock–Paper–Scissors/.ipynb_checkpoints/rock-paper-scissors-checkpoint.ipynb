# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Rock, Paper & Scissors
#
# Let's play the famous game against our computer. You can check the rules [here](https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors).
#
# ## Task
# Create a program that imitates the playability of the well known game of rock, paper, scissors. Follow the guidelines provided.
#
# ## Tools
# 1. Loop: **for/while**
# 2. Functions: **input(), print()...**
# 3. Conditional statements: **if, elif, else**
# 4. Definition of functions. Modular programming
# 5. Import modules
#
# **To solve this challenge, the use of functions is recommended.**
#
# #### 1. Import the choice function of the random module.

# %%
import random

# %% [markdown]
# #### 2. Create a list that includes the 3 possible gesture options of the game: 'rock', 'paper' or 'scissors'. Store the list in a variable called `gestures`.

# %%
gestures = ['rock', 'paper', 'scissors']

# %% [markdown]
# #### 3. Create a variable called `n_rounds` to store the maximum number of rounds to play in a game.
# Remember that the number of rounds must be odd: 1, 3, 5, ...

# %%
n_rounds = 5

# %% [markdown]
# #### 4. Create a variable called `rounds_to_win` to store the number of rounds that a player must win to win the game.
# **Hint**: the value stored in `rounds_to_win` depends on the value of `n_rounds`.

# %%
rounds_to_win = 3

# %% [markdown]
# #### 5. Create two variables to store the number of rounds that the computer and the player have won. Call these variables `cpu_score` and `player_score`.

# %%
cpu_score = 0
player_score = 0

# %% [markdown]
# #### 6. Define a function that randomly returns one of the 3 gesture options.
# You will use this function to simulate the gesture choice of the computer.

# %%
def gesture_option():
    rd = random.randint(0, 2)
    option = gestures[rd]
    return(option)

# %% [markdown]
# #### 7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'.
# The player should only be allowed to choose one of the 3 gesture options. If the player's choice is not rock, paper or scissors, keep asking until it is.

# %%
def player_option():
    i = 0
    while i == 0:
            gesture = input('What gesture do you choose between rock, paper or scissors? ')
            gestures = ['paper', 'rock', 'scissors']
            if gesture not in gestures:
                print('Wrong choice.')
            else:
                return(gesture)

# %% [markdown]
# #### 8. Define a function that checks who won a round.
# The function should return 0 if there is a tie, 1 if the computer wins and 2 if the player wins.

# %%
def round_winner(cpu, user):
    if cpu == 'scissors' and user == 'scissors':
        return(0)
    elif cpu == 'scissors' and user == 'paper':
        return(1)
    elif cpu == 'rock' and user == 'rock':
        return(0)
    elif cpu == 'rock' and user == 'scissors':
        return(1)
    elif cpu == 'paper' and user == 'paper':
        return(0)
    elif cpu == 'paper' and user == 'rock':
        return(1)
    elif user == 'scissors' and cpu == 'paper':
        return(2)
    elif user == 'rock' and cpu == 'scissors':
        return(2)
    elif user == 'paper' and cpu == 'rock':
        return(2)

# %% [markdown]
# #### 9. Define a function that prints the choice of the computer, the choice of the player and a message that announces who won the current round.
# You should also use this function to update the variables that count the number of rounds that the computer and the player have won. The score of the winner increases by one point. If there is a tie, the score does not increase.

# %%
def announcements(cpu, user):
    print('The computer choose:', cpu)
    print('The player choose:', user)
    
    winner = round_winner(cpu, user)
    if winner == 0:
        print('The round is tied')
    elif winner == 2:
        print('The round is won by the player')
    elif winner == 1:
        print('The round is won by the CPU')

# %% [markdown]
# #### 10. Now it's time to code the execution of the game using the functions and variables you defined above.
#
# First, create a loop structure that repeats while no player reaches the minimum score necessary to win and the number of rounds is less than the maximum number of rounds to play in a game.
#
# Inside the loop, use the functions and variables above to create the execution of a round: ask for the player's choice, generate the random choice of the computer, show the round results, update the scores, etc.

# %%
for i in range(5):
    cpu = gesture_option()
    user = player_option()
    winners = round_winner(cpu, user)
    print('Round:', i +1)
    announcements(cpu, user)
    
    if winners == 2:
        player_score = player_score + 1
    elif winners == 1:
        cpu_score = cpu_score + 1
# Out:
# What gesture do you choose between rock, paper or scissors? scissors
# Round: 1
# The computer choose: paper
# The player choose: scissors
# The round is won by the player
# What gesture do you choose between rock, paper or scissors? rock
# Round: 2
# The computer choose: rock
# The player choose: rock
# The round is tied
# What gesture do you choose between rock, paper or scissors? paper
# Round: 3
# The computer choose: paper
# The player choose: paper
# The round is tied
# What gesture do you choose between rock, paper or scissors? paper
# Round: 4
# The computer choose: rock
# The player choose: paper
# The round is won by the player
# What gesture do you choose between rock, paper or scissors? rock
# Round: 5
# The computer choose: scissors
# The player choose: rock
# The round is won by the player

# %% [markdown]
# #### 11. Print the winner of the game based on who won more rounds.
# Remember that the game might be tied.

# %%
if player_score > cpu_score:
    print('The user won the game')
elif player_score < cpu_score:
    print('The cpu won the game')
else:
    print('The game ended tie')
# Out:
# The user won the game

# %% [markdown]
# # Bonus: Rock, Paper, Scissors, Lizard & Spock
# ![](images/rpsls.jpg)
#
# In this challenge, you need to improve the previous game by adding two new options. To know more about the rules of the improved version of rock, paper, scissors, check this [link](http://www.samkass.com/theories/RPSSL.html).
#
# In addition, you will also need to improve how the game interacts with the player: the number of rounds to play, which must be an odd number, will be requested to the user until a valid number is entered. Define a new function to make that request.
#
# **Hint**: Try to reuse the code that you already coded in the previous challenge. If your code is efficient, this bonus will only consist of simple modifications to the original game.

# %%
gestures = ['rock', 'paper', 'scissors', 'lizard', 'spock']
n_rounds = 5
rounds_to_win = 3
cpu_score = 0
player_score = 0

def gesture_option2():
    rd = random.randint(0, 4)
    option = gestures[rd]
    return(option)

def player_option2():
    i = 0
    while i == 0:
            gesture = input('What gesture do you choose between rock, paper, scissors, spock or lizars? ')
            gestures = ['paper', 'rock', 'scissors', 'spock', 'lizard']
            if gesture not in gestures:
                print('Wrong choice.')
            else:
                return(gesture)
    

def round_winner(cpu, user):
    if cpu == 'scissors' and user == 'scissors':
        return(0)
    elif cpu == 'scissors' and user == 'paper':
        return(1)
    elif cpu == 'scissors' and user == 'lizard':
        return(1)
    elif cpu == 'rock' and user == 'rock':
        return(0)
    elif cpu == 'rock' and user == 'scissors':
        return(1)
    elif cpu == 'rock' and user == 'spock':
        return(1)
    elif cpu == 'paper' and user == 'paper':
        return(0)
    elif cpu == 'paper' and user == 'rock':
        return(1)
    elif cpu == 'paper' and user == 'spock':
        return(1)
    elif cpu == 'spock' and user == 'spock':
        return(0)
    elif cpu == 'spock' and user == 'rock':
        return(1)
    elif cpu == 'spock' and user == 'scissors':
        return(1)
    elif cpu == 'lizard' and user == 'lizard':
        return(0)
    elif cpu == 'lizard' and user == 'spock':
        return(1)
    elif cpu == 'lizard' and user == 'paper':
        return(1)
    elif user == 'scissors' and cpu == 'paper':
        return(2)
    elif user == 'scissors' and cpu == 'lizard':
        return(2)
    elif user == 'rock' and cpu == 'scissors':
        return(2)
    elif user == 'rock' and cpu == 'lizard':
        return(2)
    elif user == 'paper' and cpu == 'rock':
        return(2)
    elif user == 'paper' and cpu == 'spock':
        return(2)
    elif user == 'lizard' and cpu == 'spock':
        return(2)
    elif user == 'lizard' and cpu == 'paper':
        return(2)
    elif user == 'spock' and cpu == 'rock':
        return(2)
    elif user == 'spock' and cpu == 'scissors':
        return(2)

def announcements(cpu, user):
    print('The computer choose:', cpu)
    print('The player choose:', user)
    
    winner = round_winner(cpu, user)
    if winner == 0:
        print('The round is tied')
    elif winner == 2:
        print('The round is won by the player')
    elif winner == 1:
        print('The round is won by the CPU')
        
for i in range(5):
    cpu = gesture_option2()
    user = player_option2()
    winners = round_winner(cpu, user)
    print('Round:', i + 1)
    announcements(cpu, user)
    
    if winners == 2:
        player_score = player_score + 1
    elif winners == 1:
        cpu_score = cpu_score + 1
        
if player_score > cpu_score:
    print('The user won the game')
elif player_score < cpu_score:
    print('The cpu won the game')
else:
    print('The game ended tie')
# Out:
# What gesture do you choose between rock, paper, scissors, spock or lizars? spock
# Round: 1
# The computer choose: lizard
# The player choose: spock
# The round is won by the CPU
# What gesture do you choose between rock, paper, scissors, spock or lizars? lizard
# Round: 2
# The computer choose: scissors
# The player choose: lizard
# The round is won by the CPU
# What gesture do you choose between rock, paper, scissors, spock or lizars? lizard
# Round: 3
# The computer choose: scissors
# The player choose: lizard
# The round is won by the CPU
# What gesture do you choose between rock, paper, scissors, spock or lizars? rock
# Round: 4
# The computer choose: spock
# The player choose: rock
# The round is won by the CPU
# What gesture do you choose between rock, paper, scissors, spock or lizars? paper
# Round: 5
# The computer choose: rock
# The player choose: paper
# The round is won by the player
# The cpu won the game
